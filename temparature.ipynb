# %%
#import all necessary libaries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#loading data set
ds=pd.read_csv("temparature.csv")

# %%
ds.head()
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  30-06-2013          28.7          21.4    58.255688    91.116364
# 1      2.0  30-06-2013          31.9          21.6    52.263397    90.604721
# 2      3.0  30-06-2013          31.6          23.3    48.690479    83.973587
# 3      4.0  30-06-2013          32.0          23.4    58.239788    96.483688
# 4      5.0  30-06-2013          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Date              7750 non-null   object
#  2   Present_Tmax      7682 non-null   float64
#  3   Present_Tmin      7682 non-null   float64
#  4   LDAPS_RHmin       7677 non-null   float64
#  5   LDAPS_RHmax       7677 non-null   float64
#  6   LDAPS_Tmax_lapse  7677 non-null   float64
#  7   LDAPS_Tmin_lapse  7677 non-null   float64
#  8   LDAPS_WS          7677 non-null   float64
#  9   LDAPS_LH          7677 non-null   float64
#  10  LDAPS_CC1         7677 non-null   float64
#  11  LDAPS_CC2         7677 non-null   float64
#  12  LDAPS_CC3         7677 non-null   float64
#  13  LDAPS_CC4         7677 non-null   float64
#  14  LDAPS_PPT1        7677 non-null   float64
#  15  LDAPS_PPT2        7677 non-null   float64
# ...

# %% [markdown]
# # Checking data type

# %%
ds.dtypes
# Out:
# station             float64
# Date                 object
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %% [markdown]
# data set have float type data

# %%
ds.shape
# Out:
# (7752, 25)

# %% [markdown]
# data set have 7752 rows and 25 columns

# %% [markdown]
# # Checking null values

# %%
ds.isnull().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %% [markdown]
# data set have missing values

# %%
sns.heatmap(ds.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# above heatmap shows that there are missing values in data set

# %%
#loading data set into pandas dataframe
df=pd.DataFrame(ds)

# %%
df.head()
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  30-06-2013          28.7          21.4    58.255688    91.116364
# 1      2.0  30-06-2013          31.9          21.6    52.263397    90.604721
# 2      3.0  30-06-2013          31.6          23.3    48.690479    83.973587
# 3      4.0  30-06-2013          32.0          23.4    58.239788    96.483688
# 4      5.0  30-06-2013          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
# ...

# %% [markdown]
# # stastical summary

# %%
df.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7750.000000   7682.000000   7682.000000  7677.000000  7677.000000
# mean     13.000000     29.768211     23.225059    56.759372    88.374804
# std       7.211568      2.969999      2.413961    14.668111     7.192004
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.700000    45.963543    84.222862
# 50%      13.000000     29.900000     23.400000    55.039024    89.793480
# 75%      19.000000     32.000000     24.900000    67.190056    93.743629
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7677.000000       7677.000000  7677.000000  7677.000000
# mean          29.613447         23.512589     7.097875    62.505019
# std            2.947191          2.345347     2.183836    33.730589
# ...

# %% [raw]
# count values shows that there are missing values present in data set
# mean and median values have difference that means there is skewness present in data set
# 75% and max values are different means there are outliers present

# %% [markdown]
# # Checking corelation

# %%
df.corr()
# Out:
#                    station  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# station           1.000000      0.113211      0.132419    -0.067122
# Present_Tmax      0.113211      1.000000      0.618760    -0.206782
# Present_Tmin      0.132419      0.618760      1.000000     0.124921
# LDAPS_RHmin      -0.067122     -0.206782      0.124921     1.000000
# LDAPS_RHmax      -0.168010     -0.304209     -0.015334     0.579141
# LDAPS_Tmax_lapse  0.069561      0.575289      0.470118    -0.564580
# LDAPS_Tmin_lapse  0.105422      0.629247      0.772921     0.089476
# LDAPS_WS          0.005320     -0.122876     -0.035111     0.294361
# LDAPS_LH         -0.134226      0.136716     -0.009368    -0.070858
# LDAPS_CC1         0.006956     -0.314863      0.085593     0.613818
# LDAPS_CC2         0.003414     -0.215816      0.091439     0.745443
# LDAPS_CC3         0.000698     -0.145513     -0.002839     0.689679
# LDAPS_CC4         0.006159     -0.142497     -0.045091     0.514075
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True,cmap='Blues_r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# above heatmap shows the corelation between target variables and input features

# %%
#drop date column
df.drop("Date",axis=1,inplace=True)

# %%
for i in df.columns:
    sns.distplot(df[i])
    plt.figure()

# %% [markdown]
# above distplot shows that there are skewness present in some columns such as LDAPS_RHmax,LDPAPS_WS etc

# %% [markdown]
# Fill missing values

# %%
df['station']=df['station'].fillna(df['station'].mean())

# %%
df['Present_Tmax']=df['Present_Tmax'].fillna(df['Present_Tmax'].mean())
df['Present_Tmin']=df['Present_Tmin'].fillna(df['Present_Tmin'].mean())
df['LDAPS_RHmin']=df['LDAPS_RHmin'].fillna(df['LDAPS_RHmin'].mean())
df['LDAPS_RHmax']=df['LDAPS_RHmax'].fillna(df['LDAPS_RHmax'].median())
df['LDAPS_Tmax_lapse']=df['LDAPS_Tmax_lapse'].fillna(df['LDAPS_Tmax_lapse'].mean())
df['LDAPS_Tmin_lapse']=df['LDAPS_Tmin_lapse'].fillna(df['LDAPS_Tmin_lapse'].mean())
df['LDAPS_WS']=df['LDAPS_WS'].fillna(df['LDAPS_WS'].median())
df['LDAPS_LH']=df['LDAPS_LH'].fillna(df['LDAPS_LH'].median())
df['LDAPS_CC1']=df['LDAPS_CC1'].fillna(df['LDAPS_CC1'].median())
df['LDAPS_CC2']=df['LDAPS_CC2'].fillna(df['LDAPS_CC2'].median())
df['LDAPS_CC3']=df['LDAPS_CC3'].fillna(df['LDAPS_CC3'].median())
df['LDAPS_CC4']=df['LDAPS_CC4'].fillna(df['LDAPS_CC4'].median())
df['LDAPS_PPT1']=df['LDAPS_PPT1'].fillna(df['LDAPS_PPT1'].mean())
df['LDAPS_PPT2']=df['LDAPS_PPT2'].fillna(df['LDAPS_PPT2'].mean())
df['LDAPS_PPT3']=df['LDAPS_PPT3'].fillna(df['LDAPS_PPT3'].mean())
df['LDAPS_PPT4']=df['LDAPS_PPT4'].fillna(df['LDAPS_PPT4'].mean())
df['Next_Tmax']=df['Next_Tmax'].fillna(df['Next_Tmax'].mean())
df['Next_Tmin']=df['Next_Tmin'].fillna(df['Next_Tmin'].mean())

# %%
df.isnull().sum()
# Out:
# station             0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %% [markdown]
# now there is no missing values

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# above heatmap shows that there are no missing values

# %%
df.skew()
# Out:
# station             0.000000
# Present_Tmax       -0.264137
# Present_Tmin       -0.367538
# LDAPS_RHmin         0.300220
# LDAPS_RHmax        -0.860210
# LDAPS_Tmax_lapse   -0.227880
# LDAPS_Tmin_lapse   -0.581763
# LDAPS_WS            1.584975
# LDAPS_LH            0.678315
# LDAPS_CC1           0.465003
# LDAPS_CC2           0.477041
# LDAPS_CC3           0.646670
# LDAPS_CC4           0.673700
# LDAPS_PPT1          5.393821
# LDAPS_PPT2          5.775355
# LDAPS_PPT3          6.457129
# LDAPS_PPT4          6.825464
# lat                 0.087062
# lon                -0.285213
# DEM                 1.723257
# Slope               1.563020
# Solar radiation    -0.511210
# Next_Tmax          -0.340200
# Next_Tmin          -0.404447
# dtype: float64

# %%
df.iloc[:,:8].plot(kind='box',figsize=(15,10))
plt.subplots_adjust(bottom=0.25)

# %%
df.iloc[:,8:15].plot(kind='box',figsize=(15,10))
plt.subplots_adjust(bottom=0.25)

# %%
df.iloc[:,15:].plot(kind='box',figsize=(15,10))
plt.subplots_adjust(bottom=0.25)

# %% [markdown]
# above boxplots shows that there are outliers present so we have remove it

# %%
#remove outliers using zscore
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))

# %%
z
# Out:
# array([[1.6643153 , 0.36132577, 0.75952931, ..., 1.51793488, 0.37628214,
#         0.6975993 ],
#        [1.52562236, 0.72108401, 0.6762959 , ..., 1.22994952, 0.07209725,
#         0.17406357],
#        [1.38692941, 0.61960809, 0.03118815, ..., 1.21653443, 0.26425985,
#         0.38974413],
#        ...,
#        [1.6643153 , 2.22171758, 2.42419767, ..., 2.0743251 , 0.79263444,
#         2.2279345 ],
#        [0.        , 3.30412736, 4.9628169 , ..., 2.35821196, 4.12345278,
#         4.68452522],
#        [0.        , 2.64912642, 2.77789093, ..., 1.51793488, 2.76237361,
#         2.76579089]])

# %%
print(np.where(z>3))
# Out:
# (array([  25,   25,   26, ..., 7751, 7751, 7751], dtype=int64), array([ 7, 14, 14, ..., 14, 15, 16], dtype=int64))

# %%
df2=df[(z<3).all(axis=1)]

# %%
print("shape before removing outliers",df.shape)
print("shape after removing outliers",df2.shape)
# Out:
# shape before removing outliers (7752, 24)
# shape after removing outliers (6894, 24)

# %%
df2.head()
# Out:
#    station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0          28.7          21.4    58.255688    91.116364
# 1      2.0          31.9          21.6    52.263397    90.604721
# 2      3.0          31.6          23.3    48.690479    83.973587
# 3      4.0          32.0          23.4    58.239788    96.483688
# 4      5.0          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_CC1  ...  \
# 0         28.074101         23.006936  6.818887   69.451805   0.233947  ...
# 1         29.850689         24.035009  5.691890   51.937448   0.225508  ...
# 2         30.091292         24.565633  6.138224   20.573050   0.209344  ...
# 3         29.704629         23.326177  5.650050   65.727144   0.216372  ...
# 4         29.113934         23.486480  5.735004  107.965535   0.151407  ...
#
#    LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM   Slope  \
# ...

# %%
df2.skew()
# Out:
# station             0.002792
# Present_Tmax       -0.272653
# Present_Tmin       -0.225479
# LDAPS_RHmin         0.305740
# LDAPS_RHmax        -0.694148
# LDAPS_Tmax_lapse   -0.109372
# LDAPS_Tmin_lapse   -0.382667
# LDAPS_WS            1.097251
# LDAPS_LH            0.574066
# LDAPS_CC1           0.600830
# LDAPS_CC2           0.506876
# LDAPS_CC3           0.708018
# LDAPS_CC4           0.720393
# LDAPS_PPT1          3.731226
# LDAPS_PPT2          4.843672
# LDAPS_PPT3          5.482625
# LDAPS_PPT4          5.927822
# lat                 0.108251
# lon                -0.275508
# DEM                 1.764031
# Slope               1.593600
# Solar radiation    -0.505353
# Next_Tmax          -0.270084
# Next_Tmin          -0.237767
# dtype: float64

# %% [markdown]
# data set have some skewness

# %%
df3=df2.iloc[:]

# %%
#remove skewness usnig cbrt
for i in df3.columns:
    if df3[i].skew()>0.5:
        df3[i]=np.cbrt(df3[i])
    if df3[i].skew()<-0.5:
        df3[i]=np.cbrt(df3[i])

# %%
df3.skew()
# Out:
# station             0.002792
# Present_Tmax       -0.272653
# Present_Tmin       -0.225479
# LDAPS_RHmin         0.305740
# LDAPS_RHmax        -0.815760
# LDAPS_Tmax_lapse   -0.109372
# LDAPS_Tmin_lapse   -0.382667
# LDAPS_WS            0.626989
# LDAPS_LH           -0.272678
# LDAPS_CC1          -3.327959
# LDAPS_CC2          -2.881831
# LDAPS_CC3          -2.572327
# LDAPS_CC4          -0.421529
# LDAPS_PPT1          1.854774
# LDAPS_PPT2          2.242623
# LDAPS_PPT3          2.392493
# LDAPS_PPT4          2.714029
# lat                 0.108251
# lon                -0.275508
# DEM                 0.934952
# Slope               0.621552
# Solar radiation    -0.570914
# Next_Tmax          -0.270084
# Next_Tmin          -0.237767
# dtype: float64

# %%
#create new dataframe of input features
x=df3.drop(['Next_Tmax','Next_Tmin'],axis=1)

# %%
#split target variables
y=df3.iloc[:,-2:]

# %%
y
# Out:
#       Next_Tmax  Next_Tmin
# 0          29.1       21.2
# 1          30.5       22.5
# 2          31.1       23.9
# 3          31.7       24.3
# 4          31.2       22.5
# ...         ...        ...
# 7745       27.6       17.7
# 7746       28.0       17.1
# 7747       28.3       18.1
# 7748       28.6       18.8
# 7749       27.8       17.4
#
# [6894 rows x 2 columns]

# %%
#import regression algorithmns
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split,cross_validate

# %%
#standalied data using standardscaler
from sklearn.preprocessing import StandardScaler

# %%
st=StandardScaler()

# %%
x1=st.fit_transform(x)

# %%
x2=pd.DataFrame(x1,columns=x.columns)

# %% [markdown]
# Split data for training and testing

# %%
x1_train,x1_test,y_train,y_test=train_test_split(x2,y,test_size=.30,random_state=47)

# %%
print("x1_train shape",x1_train.shape)
print("x1_test shape",x1_test.shape)
print("y_train shape",y_train.shape)
print("y_test shape",y_test.shape)
# Out:
# x1_train shape (4825, 22)
# x1_test shape (2069, 22)
# y_train shape (4825, 2)
# y_test shape (2069, 2)

# %%
lg=LinearRegression()
dtr=DecisionTreeRegressor()
sv=SVR()
knn=KNeighborsRegressor()
rfr=RandomForestRegressor()

# %%
#fit data into models and predict values
list1=[lg,dtr,knn,rfr]
for i in list1:
    i.fit(x1_train,y_train)
    pred=i.predict(x1_test)
    print("accuracy_scores",i)
    print("r2_score",r2_score(y_test,pred))
    print("mean_squared_error",mean_squared_error(y_test,pred))
    print("mean_absolute_error",mean_absolute_error(y_test,pred))
# Out:
# accuracy_scores LinearRegression()
# r2_score 0.7753758500764806
# mean_squared_error 1.6065777609918195
# mean_absolute_error 0.9688852671698354
# accuracy_scores DecisionTreeRegressor()
# r2_score 0.7190654554513943
# mean_squared_error 1.975280153360198
# mean_absolute_error 1.0151557981045491
# accuracy_scores KNeighborsRegressor()
# r2_score 0.823429716253167
# mean_squared_error 1.252410919835453
# mean_absolute_error 0.841044050797643
# accuracy_scores RandomForestRegressor()
# r2_score 0.8785456181004291
# mean_squared_error 0.8487262261737487
# mean_absolute_error 0.7008617533289221

# %% [markdown]
# by abserving above accuracy matrix random forest gives very less errors

# %%
#checking cross val scores
for i in list1:
    
    scores = cross_validate(i, x2, y, cv=5,scoring=('r2', 'neg_mean_squared_error'),return_train_score=True)
    print("cross_validates_scores",i)
    print(scores['test_neg_mean_squared_error'])
    print(scores["train_r2"])
# Out:
# cross_validates_scores LinearRegression()
# [-1.67414231 -2.01271205 -1.69602105 -2.31601168 -2.09057781]
# [0.78344029 0.78462472 0.78047531 0.75564466 0.78101902]
# cross_validates_scores DecisionTreeRegressor()
# [-3.79435164 -4.04539017 -3.96144456 -3.51383199 -3.66915108]
# [1. 1. 1. 1. 1.]
# cross_validates_scores KNeighborsRegressor()
# [-2.23845697 -3.0782103  -2.49489518 -3.22178266 -2.76958924]
# [0.89625203 0.89561757 0.89960792 0.88351763 0.90538556]
# cross_validates_scores RandomForestRegressor()
# [-1.68956522 -2.04837325 -1.82501084 -2.25307734 -2.20816273]
# [0.98560261 0.98543609 0.98557529 0.98363621 0.98555224]

# %%
from sklearn.model_selection import cross_val_score
for i in list1:
    cv1=cross_val_score(i,x2,y,cv=5)
    print("cross_val_scores",i)
    print("scores",cv1)
    print(cv1.mean())
# Out:
# cross_val_scores LinearRegression()
# scores [0.68128186 0.64584828 0.72698529 0.74895725 0.73038128]
# 0.7066907951783448
# cross_val_scores DecisionTreeRegressor()
# scores [0.27232747 0.30358649 0.38337483 0.58047616 0.50051318]
# 0.4080556246014277
# cross_val_scores KNeighborsRegressor()
# scores [0.54082245 0.46045002 0.59545545 0.64294212 0.63368716]
# 0.5746714396273864
# cross_val_scores RandomForestRegressor()
# scores [0.66172739 0.64248514 0.70394317 0.75898447 0.71520283]
# 0.6964685996627523

# %% [markdown]
# # HyperparameterTunning

# %%
from sklearn.model_selection import GridSearchCV
param_grid = { 
            "n_estimators"      : [10,20,30],
            "max_features"      : ["auto", "sqrt", "log2"],
            "min_samples_split" : [2,4,8],
            "bootstrap": [True, False],
            }

grid = GridSearchCV(estimator=rfr, param_grid=param_grid, n_jobs=-1, cv=5)

grid.fit(x1_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_split': [2, 4, 8],
#                          'n_estimators': [10, 20, 30]})

# %%
print(grid.best_score_)
print(grid.best_params_)
# Out:
# 0.8881004668801264
# {'bootstrap': False, 'max_features': 'log2', 'min_samples_split': 4, 'n_estimators': 30}

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(bootstrap=False,max_features= 'log2',min_samples_split=4,n_estimators=30)
rf.fit(x1_train,y_train)
rpred=rf.predict(x1_test)
cv3=cross_val_score(rf,x2,y,cv=5)
print("score",cv3)
print("cross score mean value",cv3.mean())
print('mean squared error',mean_squared_error(rpred,y_test))
# Out:
# score [0.66731487 0.61808165 0.70599202 0.75781582 0.71398896]
# cross score mean value 0.6926386613677629
# mean squared error 0.7496360221099434

# %% [markdown]
# by hyperparametertunning randomforestregressor performs well

# %%
import joblib

# %%
joblib.dump(rf,'Temp1.obj')
# Out:
# ['Temp1.obj']

# %% [markdown]
# created object file
